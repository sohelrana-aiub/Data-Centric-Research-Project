# %%
#print("Hi")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\hp\Videos\\Data Centric Research Fileds\\LaptopPrice_Prediction with ml\\laptop_data.csv')

# %%
df.head(50)
# Out:
#     Unnamed: 0 Company            TypeName  Inches  \
# 0            0   Apple           Ultrabook    13.3
# 1            1   Apple           Ultrabook    13.3
# 2            2      HP            Notebook    15.6
# 3            3   Apple           Ultrabook    15.4
# 4            4   Apple           Ultrabook    13.3
# 5            5    Acer            Notebook    15.6
# 6            6   Apple           Ultrabook    15.4
# 7            7   Apple           Ultrabook    13.3
# 8            8    Asus           Ultrabook    14.0
# 9            9    Acer           Ultrabook    14.0
# 10          10      HP            Notebook    15.6
# 11          11      HP            Notebook    15.6
# 12          12   Apple           Ultrabook    15.4
# 13          13    Dell            Notebook    15.6
# 14          14   Apple           Ultrabook    12.0
# 15          15   Apple           Ultrabook    13.3
# 16          16    Dell            Notebook    15.6
# 17          17   Apple           Ultrabook    15.4
# 18          18  Lenovo            Notebook    15.6
# 19          19    Dell           Ultrabook    13.3
# 20          20    Asus             Netbook    11.6
# 21          21  Lenovo              Gaming    15.6
# 22          22      HP            Notebook    15.6
# 23          23    Dell  2 in 1 Convertible    13.3
# 24          24      HP           Ultrabook    15.6
# 25          25    Dell            Notebook    15.6
# 26          26   Apple           Ultrabook    13.3
# 27          27    Dell            Notebook    15.6
# 28          28    Dell           Ultrabook    15.6
# 29          29      HP            Notebook    17.3
# 30          30   Chuwi            Notebook    15.6
# 31          31    Asus            Notebook    14.0
# 32          32      HP            Notebook    17.3
# 33          33    Dell           Ultrabook    13.3
# 34          34   Apple           Ultrabook    13.3
# 35          35  Lenovo            Notebook    14.0
# 36          36    Acer            Notebook    15.6
# 37          37    Dell            Notebook    17.3
# 38          38      HP            Notebook    15.6
# 39          39      HP            Notebook    15.6
# 40          40    Asus            Notebook    15.6
# 41          41    Dell              Gaming    15.6
# 42          42    Asus            Notebook    15.6
# 43          43    Acer            Notebook    15.6
# 44          44    Dell  2 in 1 Convertible    17.3
# 45          45   Apple           Ultrabook    13.3
# 46          46  Lenovo            Notebook    15.6
# 47          47    Asus              Gaming    17.3
# 48          48    Dell            Notebook    15.6
# 49          49    Asus            Notebook    17.3
#
#                              ScreenResolution  \
# 0          IPS Panel Retina Display 2560x1600
# 1                                    1440x900
# 2                           Full HD 1920x1080
# 3          IPS Panel Retina Display 2880x1800
# 4          IPS Panel Retina Display 2560x1600
# 5                                    1366x768
# 6          IPS Panel Retina Display 2880x1800
# 7                                    1440x900
# 8                           Full HD 1920x1080
# 9                 IPS Panel Full HD 1920x1080
# 10                                   1366x768
# 11                          Full HD 1920x1080
# 12         IPS Panel Retina Display 2880x1800
# 13                          Full HD 1920x1080
# 14         IPS Panel Retina Display 2304x1440
# 15         IPS Panel Retina Display 2560x1600
# 16                          Full HD 1920x1080
# 17         IPS Panel Retina Display 2880x1800
# 18                          Full HD 1920x1080
# 19  IPS Panel Full HD / Touchscreen 1920x1080
# 20                                   1366x768
# 21                IPS Panel Full HD 1920x1080
# 22                                   1366x768
# 23            Full HD / Touchscreen 1920x1080
# 24                          Full HD 1920x1080
# 25                                   1366x768
# 26                                   1440x900
# 27                          Full HD 1920x1080
# 28                          Full HD 1920x1080
# 29                          Full HD 1920x1080
# 30                          Full HD 1920x1080
# 31                                   1366x768
# 32                          Full HD 1920x1080
# 33           Touchscreen / Quad HD+ 3200x1800
# 34                                   1440x900
# 35                                   1366x768
# 36                                   1366x768
# 37                IPS Panel Full HD 1920x1080
# 38                                   1366x768
# 39                          Full HD 1920x1080
# 40                          Full HD 1920x1080
# 41                IPS Panel Full HD 1920x1080
# 42                                   1366x768
# 43                IPS Panel Full HD 1920x1080
# 44            Full HD / Touchscreen 1920x1080
# 45         IPS Panel Retina Display 2560x1600
# 46                                   1366x768
# 47                          Full HD 1920x1080
# 48                          Full HD 1920x1080
# 49                                   1366x768
#
#                                      Cpu   Ram                  Memory  \
# 0                   Intel Core i5 2.3GHz   8GB               128GB SSD
# 1                   Intel Core i5 1.8GHz   8GB     128GB Flash Storage
# 2             Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 3                   Intel Core i7 2.7GHz  16GB               512GB SSD
# 4                   Intel Core i5 3.1GHz   8GB               256GB SSD
# 5                AMD A9-Series 9420 3GHz   4GB               500GB HDD
# 6                   Intel Core i7 2.2GHz  16GB     256GB Flash Storage
# 7                   Intel Core i5 1.8GHz   8GB     256GB Flash Storage
# 8             Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 9             Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 10            Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
# 11              Intel Core i3 6006U 2GHz   4GB               500GB HDD
# 12                  Intel Core i7 2.8GHz  16GB               256GB SSD
# 13              Intel Core i3 6006U 2GHz   4GB               256GB SSD
# 14                Intel Core M m3 1.2GHz   8GB               256GB SSD
# 15                  Intel Core i5 2.3GHz   8GB               256GB SSD
# 16            Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 17                  Intel Core i7 2.9GHz  16GB               512GB SSD
# 18            Intel Core i3 7100U 2.4GHz   8GB                 1TB HDD
# 19            Intel Core i5 8250U 1.6GHz   8GB               128GB SSD
# 20           Intel Atom x5-Z8350 1.44GHz   2GB      32GB Flash Storage
# 21           Intel Core i5 7300HQ 2.5GHz   8GB    128GB SSD +  1TB HDD
# 22          AMD E-Series E2-9000e 1.5GHz   4GB               500GB HDD
# 23            Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 24            Intel Core i7 8550U 1.8GHz   8GB               256GB SSD
# 25              Intel Core i3 6006U 2GHz   4GB                 1TB HDD
# 26                  Intel Core i5 1.6GHz   8GB     128GB Flash Storage
# 27            Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 28            Intel Core i7 8650U 1.9GHz   8GB  256GB SSD +  256GB SSD
# 29            Intel Core i5 8250U 1.6GHz   8GB                 1TB HDD
# 30           Intel Atom x5-Z8300 1.44GHz   4GB      64GB Flash Storage
# 31           AMD E-Series E2-6110 1.5GHz   2GB      32GB Flash Storage
# 32             AMD A6-Series 9220 2.5GHz   4GB               500GB HDD
# 33            Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 34                  Intel Core i5 1.6GHz   8GB     256GB Flash Storage
# 35  Intel Celeron Dual Core N3350 1.1GHz   4GB      64GB Flash Storage
# 36            Intel Core i3 7130U 2.7GHz   4GB                 1TB HDD
# 37            Intel Core i5 8250U 1.6GHz   8GB    128GB SSD +  1TB HDD
# 38            Intel Core i5 7200U 2.5GHz   4GB                 1TB HDD
# 39            Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 40              Intel Core i3 6006U 2GHz   4GB                 1TB HDD
# 41           Intel Core i7 7700HQ 2.8GHz  16GB    256GB SSD +  1TB HDD
# 42            Intel Core i5 7200U 2.5GHz   8GB                 1TB HDD
# 43            Intel Core i5 8250U 1.6GHz   4GB               256GB SSD
# 44            Intel Core i5 8250U 1.6GHz  12GB                 1TB HDD
# 45                  Intel Core i5 2.0GHz   8GB               256GB SSD
# 46              Intel Core i3 6006U 2GHz   4GB               128GB SSD
# 47                   AMD Ryzen 1700 3GHz   8GB    256GB SSD +  1TB HDD
# 48            Intel Core i5 7200U 2.5GHz   4GB               256GB SSD
# 49  Intel Pentium Quad Core N4200 1.1GHz   4GB                 1TB HDD
#
#                              Gpu       OpSys  Weight        Price
# 0   Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1         Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2          Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3             AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4   Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# 5                  AMD Radeon R5  Windows 10   2.1kg   21312.0000
# 6        Intel Iris Pro Graphics    Mac OS X  2.04kg  114017.6016
# 7         Intel HD Graphics 6000       macOS  1.34kg   61735.5360
# 8           Nvidia GeForce MX150  Windows 10   1.3kg   79653.6000
# 9         Intel UHD Graphics 620  Windows 10   1.6kg   41025.6000
# 10         Intel HD Graphics 620       No OS  1.86kg   20986.9920
# 11         Intel HD Graphics 520       No OS  1.86kg   18381.0672
# 12            AMD Radeon Pro 555       macOS  1.83kg  130001.6016
# 13            AMD Radeon R5 M430  Windows 10   2.2kg   26581.3920
# 14         Intel HD Graphics 615       macOS  0.92kg   67260.6720
# 15  Intel Iris Plus Graphics 640       macOS  1.37kg   80908.3440
# 16            AMD Radeon R5 M430  Windows 10   2.2kg   39693.6000
# 17            AMD Radeon Pro 560       macOS  1.83kg  152274.2400
# 18          Nvidia GeForce 940MX       No OS   2.2kg   26586.7200
# 19        Intel UHD Graphics 620  Windows 10  1.22kg   52161.1200
# 20         Intel HD Graphics 400  Windows 10  0.98kg   10224.4320
# 21       Nvidia GeForce GTX 1050  Windows 10   2.5kg   53226.7200
# 22                 AMD Radeon R2       No OS  1.86kg   13746.2400
# 23        Intel UHD Graphics 620  Windows 10  1.62kg   43636.3200
# 24         Intel HD Graphics 620  Windows 10  1.91kg   35111.5200
# 25         Intel HD Graphics 520  Windows 10   2.3kg   22305.1392
# 26        Intel HD Graphics 6000    Mac OS X  1.35kg   58554.7200
# 27                AMD Radeon 530  Windows 10   2.2kg   42624.0000
# 28        Intel UHD Graphics 620  Windows 10  1.88kg   69157.4400
# 29          Nvidia GeForce 930MX  Windows 10   2.5kg   47738.8800
# 30             Intel HD Graphics  Windows 10  1.89kg   13053.0672
# 31                 AMD Radeon R2  Windows 10  1.65kg   10602.7200
# 32                AMD Radeon 530  Windows 10  2.71kg   23389.9200
# 33        Intel UHD Graphics 620  Windows 10   1.2kg   99580.3200
# 34        Intel HD Graphics 6000    Mac OS X  1.35kg   53173.4400
# 35         Intel HD Graphics 500  Windows 10  1.44kg   13266.7200
# 36         Intel HD Graphics 620       Linux   2.1kg   19553.7600
# 37                AMD Radeon 530  Windows 10   2.8kg   52161.1200
# 38         Intel HD Graphics 620  Windows 10  1.86kg   26037.4032
# 39         Nvidia GeForce 930MX   Windows 10   2.1kg   46833.1200
# 40         Intel HD Graphics 620       Linux     2kg   20725.9200
# 41       Nvidia GeForce GTX 1060  Windows 10  2.65kg   79866.7200
# 42          Nvidia GeForce 940MX       Linux   2.3kg   27864.9072
# 43        Intel UHD Graphics 620  Windows 10   2.2kg   36336.9600
# 44          Nvidia GeForce 150MX  Windows 10  2.77kg   53226.7200
# 45       Intel Iris Graphics 540       macOS  1.37kg   75604.3200
# 46         Intel HD Graphics 520       No OS   2.2kg   19660.3200
# 47             AMD Radeon RX 580  Windows 10   3.2kg   69210.7200
# 48            AMD Radeon R5 M430  Windows 10   2.3kg   34045.9200
# 49          Nvidia GeForce 920MX  Windows 10   2.8kg   24828.4800

# %%
df.tail()
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                         Gpu       OpSys  Weight     Price
# 1298  Intel HD Graphics 520  Windows 10   1.8kg  33992.64
# 1299  Intel HD Graphics 520  Windows 10   1.3kg  79866.72
# 1300      Intel HD Graphics  Windows 10   1.5kg  12201.12
# 1301     AMD Radeon R5 M330  Windows 10  2.19kg  40705.92
# 1302      Intel HD Graphics  Windows 10   2.2kg  19660.32

# %% [markdown]
# Data Engineering, EDA, Data Visualizations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head(100)
# Out:
#    Company            TypeName  Inches  \
# 0    Apple           Ultrabook    13.3
# 1    Apple           Ultrabook    13.3
# 2       HP            Notebook    15.6
# 3    Apple           Ultrabook    15.4
# 4    Apple           Ultrabook    13.3
# ..     ...                 ...     ...
# 95    Acer  2 in 1 Convertible    13.3
# 96    Dell            Notebook    15.6
# 97    Dell            Notebook    15.6
# 98    Asus            Notebook    15.6
# 99      HP              Gaming    15.6
#
#                              ScreenResolution                          Cpu  \
# 0          IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 1                                    1440x900         Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 3          IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz
# 4          IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz
# ..                                        ...                          ...
# 95  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 96                          Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 97                          Full HD 1920x1080     Intel Core i3 6006U 2GHz
# 98                          Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# 99                IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#      Ram                Memory                           Gpu       OpSys  \
# 0    8GB             128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1    8GB   128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2    8GB             256GB SSD         Intel HD Graphics 620       No OS
# 3   16GB             512GB SSD            AMD Radeon Pro 455       macOS
# 4    8GB             256GB SSD  Intel Iris Plus Graphics 650       macOS
# ..   ...                   ...                           ...         ...
# 95   8GB             256GB SSD        Intel UHD Graphics 620  Windows 10
# 96   8GB               1TB HDD            AMD Radeon R5 M430       Linux
# 97   4GB             256GB SSD            AMD Radeon R5 M430       Linux
# 98   6GB             256GB SSD           Nvidia GeForce 920M  Windows 10
# 99  12GB  128GB SSD +  1TB HDD       Nvidia GeForce GTX 1050  Windows 10
#
#     Weight        Price
# 0   1.37kg   71378.6832
# 1   1.34kg   47895.5232
# 2   1.86kg   30636.0000
# 3   1.83kg  135195.3360
# 4   1.37kg   96095.8080
# ..     ...          ...
# 95   1.5kg   45128.1600
# 96   2.2kg   31962.6720
# 97   2.2kg   25840.8000
# 98     2kg   30742.5600
# 99  2.62kg   66546.7200
#
# [100 rows x 11 columns]

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head(100)
# Out:
#    Company            TypeName  Inches  \
# 0    Apple           Ultrabook    13.3
# 1    Apple           Ultrabook    13.3
# 2       HP            Notebook    15.6
# 3    Apple           Ultrabook    15.4
# 4    Apple           Ultrabook    13.3
# ..     ...                 ...     ...
# 95    Acer  2 in 1 Convertible    13.3
# 96    Dell            Notebook    15.6
# 97    Dell            Notebook    15.6
# 98    Asus            Notebook    15.6
# 99      HP              Gaming    15.6
#
#                              ScreenResolution                          Cpu  \
# 0          IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 1                                    1440x900         Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 3          IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz
# 4          IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz
# ..                                        ...                          ...
# 95  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 96                          Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 97                          Full HD 1920x1080     Intel Core i3 6006U 2GHz
# 98                          Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# 99                IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#    Ram                Memory                           Gpu       OpSys Weight  \
# 0    8             128GB SSD  Intel Iris Plus Graphics 640       macOS   1.37
# 1    8   128GB Flash Storage        Intel HD Graphics 6000       macOS   1.34
# 2    8             256GB SSD         Intel HD Graphics 620       No OS   1.86
# 3   16             512GB SSD            AMD Radeon Pro 455       macOS   1.83
# 4    8             256GB SSD  Intel Iris Plus Graphics 650       macOS   1.37
# ..  ..                   ...                           ...         ...    ...
# 95   8             256GB SSD        Intel UHD Graphics 620  Windows 10    1.5
# 96   8               1TB HDD            AMD Radeon R5 M430       Linux    2.2
# 97   4             256GB SSD            AMD Radeon R5 M430       Linux    2.2
# 98   6             256GB SSD           Nvidia GeForce 920M  Windows 10      2
# 99  12  128GB SSD +  1TB HDD       Nvidia GeForce GTX 1050  Windows 10   2.62
#
#           Price
# 0    71378.6832
# 1    47895.5232
# 2    30636.0000
# 3   135195.3360
# 4    96095.8080
# ..          ...
# 95   45128.1600
# 96   31962.6720
# 97   25840.8000
# 98   30742.5600
# 99   66546.7200
#
# [100 rows x 11 columns]

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.describe()
# Out:
#             Inches          Ram       Weight          Price
# count  1303.000000  1303.000000  1303.000000    1303.000000
# mean     15.017191     8.382195     2.038733   59870.042910
# std       1.426304     5.084665     0.665475   37243.201786
# min      10.100000     2.000000     0.690000    9270.720000
# 25%      14.000000     4.000000     1.500000   31914.720000
# 50%      15.600000     8.000000     2.040000   52054.560000
# 75%      15.600000     8.000000     2.300000   79274.246400
# max      18.400000    64.000000     4.700000  324954.720000

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7464\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7464\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7464\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080    1

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 202     Acer            Notebook    15.6
# 1000    Acer              Gaming    15.6
# 376   Lenovo             Netbook    11.6
# 736       HP         Workstation    15.6
# 250     Dell  2 in 1 Convertible    15.6
#
#                                ScreenResolution  \
# 202                           Full HD 1920x1080
# 1000                IPS Panel Full HD 1920x1080
# 376                          IPS Panel 1366x768
# 736                           Full HD 1920x1080
# 250   IPS Panel Full HD / Touchscreen 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 202             Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 1000           Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
# 376   Intel Celeron Quad Core N3450 1.1GHz    4             128GB SSD
# 736            Intel Core i7 7700HQ 2.8GHz   16             256GB SSD
# 250             Intel Core i7 8550U 1.8GHz    8               1TB HDD
#
#                           Gpu       OpSys  Weight      Price  Ips  \
# 202      Nvidia GeForce 940MX  Windows 10    2.23   39533.76    0
# 1000  Nvidia GeForce GTX 1050  Windows 10    2.70   67132.80    1
# 376     Intel HD Graphics 500  Windows 10    1.59   29463.84    1
# 736       Nvidia Quadro M2200  Windows 10    2.60  128884.32    0
# 250    Intel UHD Graphics 620  Windows 10    2.08   43636.32    1
#
#                                      X_res Y_res
# 202                           Full HD 1920  1080
# 1000                IPS Panel Full HD 1920  1080
# 376                         IPS Panel 1366   768
# 736                           Full HD 1920  1080
# 250   IPS Panel Full HD / Touchscreen 1920  1080

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head(50)
# Out:
#    Company            TypeName  Inches  \
# 0    Apple           Ultrabook    13.3
# 1    Apple           Ultrabook    13.3
# 2       HP            Notebook    15.6
# 3    Apple           Ultrabook    15.4
# 4    Apple           Ultrabook    13.3
# 5     Acer            Notebook    15.6
# 6    Apple           Ultrabook    15.4
# 7    Apple           Ultrabook    13.3
# 8     Asus           Ultrabook    14.0
# 9     Acer           Ultrabook    14.0
# 10      HP            Notebook    15.6
# 11      HP            Notebook    15.6
# 12   Apple           Ultrabook    15.4
# 13    Dell            Notebook    15.6
# 14   Apple           Ultrabook    12.0
# 15   Apple           Ultrabook    13.3
# 16    Dell            Notebook    15.6
# 17   Apple           Ultrabook    15.4
# 18  Lenovo            Notebook    15.6
# 19    Dell           Ultrabook    13.3
# 20    Asus             Netbook    11.6
# 21  Lenovo              Gaming    15.6
# 22      HP            Notebook    15.6
# 23    Dell  2 in 1 Convertible    13.3
# 24      HP           Ultrabook    15.6
# 25    Dell            Notebook    15.6
# 26   Apple           Ultrabook    13.3
# 27    Dell            Notebook    15.6
# 28    Dell           Ultrabook    15.6
# 29      HP            Notebook    17.3
# 30   Chuwi            Notebook    15.6
# 31    Asus            Notebook    14.0
# 32      HP            Notebook    17.3
# 33    Dell           Ultrabook    13.3
# 34   Apple           Ultrabook    13.3
# 35  Lenovo            Notebook    14.0
# 36    Acer            Notebook    15.6
# 37    Dell            Notebook    17.3
# 38      HP            Notebook    15.6
# 39      HP            Notebook    15.6
# 40    Asus            Notebook    15.6
# 41    Dell              Gaming    15.6
# 42    Asus            Notebook    15.6
# 43    Acer            Notebook    15.6
# 44    Dell  2 in 1 Convertible    17.3
# 45   Apple           Ultrabook    13.3
# 46  Lenovo            Notebook    15.6
# 47    Asus              Gaming    17.3
# 48    Dell            Notebook    15.6
# 49    Asus            Notebook    17.3
#
#                              ScreenResolution  \
# 0          IPS Panel Retina Display 2560x1600
# 1                                    1440x900
# 2                           Full HD 1920x1080
# 3          IPS Panel Retina Display 2880x1800
# 4          IPS Panel Retina Display 2560x1600
# 5                                    1366x768
# 6          IPS Panel Retina Display 2880x1800
# 7                                    1440x900
# 8                           Full HD 1920x1080
# 9                 IPS Panel Full HD 1920x1080
# 10                                   1366x768
# 11                          Full HD 1920x1080
# 12         IPS Panel Retina Display 2880x1800
# 13                          Full HD 1920x1080
# 14         IPS Panel Retina Display 2304x1440
# 15         IPS Panel Retina Display 2560x1600
# 16                          Full HD 1920x1080
# 17         IPS Panel Retina Display 2880x1800
# 18                          Full HD 1920x1080
# 19  IPS Panel Full HD / Touchscreen 1920x1080
# 20                                   1366x768
# 21                IPS Panel Full HD 1920x1080
# 22                                   1366x768
# 23            Full HD / Touchscreen 1920x1080
# 24                          Full HD 1920x1080
# 25                                   1366x768
# 26                                   1440x900
# 27                          Full HD 1920x1080
# 28                          Full HD 1920x1080
# 29                          Full HD 1920x1080
# 30                          Full HD 1920x1080
# 31                                   1366x768
# 32                          Full HD 1920x1080
# 33           Touchscreen / Quad HD+ 3200x1800
# 34                                   1440x900
# 35                                   1366x768
# 36                                   1366x768
# 37                IPS Panel Full HD 1920x1080
# 38                                   1366x768
# 39                          Full HD 1920x1080
# 40                          Full HD 1920x1080
# 41                IPS Panel Full HD 1920x1080
# 42                                   1366x768
# 43                IPS Panel Full HD 1920x1080
# 44            Full HD / Touchscreen 1920x1080
# 45         IPS Panel Retina Display 2560x1600
# 46                                   1366x768
# 47                          Full HD 1920x1080
# 48                          Full HD 1920x1080
# 49                                   1366x768
#
#                                      Cpu  Ram                  Memory  \
# 0                   Intel Core i5 2.3GHz    8               128GB SSD
# 1                   Intel Core i5 1.8GHz    8     128GB Flash Storage
# 2             Intel Core i5 7200U 2.5GHz    8               256GB SSD
# 3                   Intel Core i7 2.7GHz   16               512GB SSD
# 4                   Intel Core i5 3.1GHz    8               256GB SSD
# 5                AMD A9-Series 9420 3GHz    4               500GB HDD
# 6                   Intel Core i7 2.2GHz   16     256GB Flash Storage
# 7                   Intel Core i5 1.8GHz    8     256GB Flash Storage
# 8             Intel Core i7 8550U 1.8GHz   16               512GB SSD
# 9             Intel Core i5 8250U 1.6GHz    8               256GB SSD
# 10            Intel Core i5 7200U 2.5GHz    4               500GB HDD
# 11              Intel Core i3 6006U 2GHz    4               500GB HDD
# 12                  Intel Core i7 2.8GHz   16               256GB SSD
# 13              Intel Core i3 6006U 2GHz    4               256GB SSD
# 14                Intel Core M m3 1.2GHz    8               256GB SSD
# 15                  Intel Core i5 2.3GHz    8               256GB SSD
# 16            Intel Core i7 7500U 2.7GHz    8               256GB SSD
# 17                  Intel Core i7 2.9GHz   16               512GB SSD
# 18            Intel Core i3 7100U 2.4GHz    8                 1TB HDD
# 19            Intel Core i5 8250U 1.6GHz    8               128GB SSD
# 20           Intel Atom x5-Z8350 1.44GHz    2      32GB Flash Storage
# 21           Intel Core i5 7300HQ 2.5GHz    8    128GB SSD +  1TB HDD
# 22          AMD E-Series E2-9000e 1.5GHz    4               500GB HDD
# 23            Intel Core i5 8250U 1.6GHz    8               256GB SSD
# 24            Intel Core i7 8550U 1.8GHz    8               256GB SSD
# 25              Intel Core i3 6006U 2GHz    4                 1TB HDD
# 26                  Intel Core i5 1.6GHz    8     128GB Flash Storage
# 27            Intel Core i5 8250U 1.6GHz    8               256GB SSD
# 28            Intel Core i7 8650U 1.9GHz    8  256GB SSD +  256GB SSD
# 29            Intel Core i5 8250U 1.6GHz    8                 1TB HDD
# 30           Intel Atom x5-Z8300 1.44GHz    4      64GB Flash Storage
# 31           AMD E-Series E2-6110 1.5GHz    2      32GB Flash Storage
# 32             AMD A6-Series 9220 2.5GHz    4               500GB HDD
# 33            Intel Core i7 8550U 1.8GHz   16               512GB SSD
# 34                  Intel Core i5 1.6GHz    8     256GB Flash Storage
# 35  Intel Celeron Dual Core N3350 1.1GHz    4      64GB Flash Storage
# 36            Intel Core i3 7130U 2.7GHz    4                 1TB HDD
# 37            Intel Core i5 8250U 1.6GHz    8    128GB SSD +  1TB HDD
# 38            Intel Core i5 7200U 2.5GHz    4                 1TB HDD
# 39            Intel Core i5 8250U 1.6GHz    8               256GB SSD
# 40              Intel Core i3 6006U 2GHz    4                 1TB HDD
# 41           Intel Core i7 7700HQ 2.8GHz   16    256GB SSD +  1TB HDD
# 42            Intel Core i5 7200U 2.5GHz    8                 1TB HDD
# 43            Intel Core i5 8250U 1.6GHz    4               256GB SSD
# 44            Intel Core i5 8250U 1.6GHz   12                 1TB HDD
# 45                  Intel Core i5 2.0GHz    8               256GB SSD
# 46              Intel Core i3 6006U 2GHz    4               128GB SSD
# 47                   AMD Ryzen 1700 3GHz    8    256GB SSD +  1TB HDD
# 48            Intel Core i5 7200U 2.5GHz    4               256GB SSD
# 49  Intel Pentium Quad Core N4200 1.1GHz    4                 1TB HDD
#
#                              Gpu       OpSys  Weight        Price  Ips X_res  \
# 0   Intel Iris Plus Graphics 640       macOS    1.37   71378.6832    1  2560
# 1         Intel HD Graphics 6000       macOS    1.34   47895.5232    0  1440
# 2          Intel HD Graphics 620       No OS    1.86   30636.0000    0  1920
# 3             AMD Radeon Pro 455       macOS    1.83  135195.3360    1  2880
# 4   Intel Iris Plus Graphics 650       macOS    1.37   96095.8080    1  2560
# 5                  AMD Radeon R5  Windows 10    2.10   21312.0000    0  1366
# 6        Intel Iris Pro Graphics    Mac OS X    2.04  114017.6016    1  2880
# 7         Intel HD Graphics 6000       macOS    1.34   61735.5360    0  1440
# 8           Nvidia GeForce MX150  Windows 10    1.30   79653.6000    0  1920
# 9         Intel UHD Graphics 620  Windows 10    1.60   41025.6000    1  1920
# 10         Intel HD Graphics 620       No OS    1.86   20986.9920    0  1366
# 11         Intel HD Graphics 520       No OS    1.86   18381.0672    0  1920
# 12            AMD Radeon Pro 555       macOS    1.83  130001.6016    1  2880
# 13            AMD Radeon R5 M430  Windows 10    2.20   26581.3920    0  1920
# 14         Intel HD Graphics 615       macOS    0.92   67260.6720    1  2304
# 15  Intel Iris Plus Graphics 640       macOS    1.37   80908.3440    1  2560
# 16            AMD Radeon R5 M430  Windows 10    2.20   39693.6000    0  1920
# 17            AMD Radeon Pro 560       macOS    1.83  152274.2400    1  2880
# 18          Nvidia GeForce 940MX       No OS    2.20   26586.7200    0  1920
# 19        Intel UHD Graphics 620  Windows 10    1.22   52161.1200    1  1920
# 20         Intel HD Graphics 400  Windows 10    0.98   10224.4320    0  1366
# 21       Nvidia GeForce GTX 1050  Windows 10    2.50   53226.7200    1  1920
# 22                 AMD Radeon R2       No OS    1.86   13746.2400    0  1366
# 23        Intel UHD Graphics 620  Windows 10    1.62   43636.3200    0  1920
# 24         Intel HD Graphics 620  Windows 10    1.91   35111.5200    0  1920
# 25         Intel HD Graphics 520  Windows 10    2.30   22305.1392    0  1366
# 26        Intel HD Graphics 6000    Mac OS X    1.35   58554.7200    0  1440
# 27                AMD Radeon 530  Windows 10    2.20   42624.0000    0  1920
# 28        Intel UHD Graphics 620  Windows 10    1.88   69157.4400    0  1920
# 29          Nvidia GeForce 930MX  Windows 10    2.50   47738.8800    0  1920
# 30             Intel HD Graphics  Windows 10    1.89   13053.0672    0  1920
# 31                 AMD Radeon R2  Windows 10    1.65   10602.7200    0  1366
# 32                AMD Radeon 530  Windows 10    2.71   23389.9200    0  1920
# 33        Intel UHD Graphics 620  Windows 10    1.20   99580.3200    0  3200
# 34        Intel HD Graphics 6000    Mac OS X    1.35   53173.4400    0  1440
# 35         Intel HD Graphics 500  Windows 10    1.44   13266.7200    0  1366
# 36         Intel HD Graphics 620       Linux    2.10   19553.7600    0  1366
# 37                AMD Radeon 530  Windows 10    2.80   52161.1200    1  1920
# 38         Intel HD Graphics 620  Windows 10    1.86   26037.4032    0  1366
# 39         Nvidia GeForce 930MX   Windows 10    2.10   46833.1200    0  1920
# 40         Intel HD Graphics 620       Linux    2.00   20725.9200    0  1920
# 41       Nvidia GeForce GTX 1060  Windows 10    2.65   79866.7200    1  1920
# 42          Nvidia GeForce 940MX       Linux    2.30   27864.9072    0  1366
# 43        Intel UHD Graphics 620  Windows 10    2.20   36336.9600    1  1920
# 44          Nvidia GeForce 150MX  Windows 10    2.77   53226.7200    0  1920
# 45       Intel Iris Graphics 540       macOS    1.37   75604.3200    1  2560
# 46         Intel HD Graphics 520       No OS    2.20   19660.3200    0  1366
# 47             AMD Radeon RX 580  Windows 10    3.20   69210.7200    0  1920
# 48            AMD Radeon R5 M430  Windows 10    2.30   34045.9200    0  1920
# 49          Nvidia GeForce 920MX  Windows 10    2.80   24828.4800    0  1366
#
#    Y_res
# 0   1600
# 1    900
# 2   1080
# 3   1800
# 4   1600
# 5    768
# 6   1800
# 7    900
# 8   1080
# 9   1080
# 10   768
# 11  1080
# 12  1800
# 13  1080
# 14  1440
# 15  1600
# 16  1080
# 17  1800
# 18  1080
# 19  1080
# 20   768
# 21  1080
# 22   768
# 23  1080
# 24  1080
# 25   768
# 26   900
# 27  1080
# 28  1080
# 29  1080
# 30  1080
# 31   768
# 32  1080
# 33  1800
# 34   900
# 35   768
# 36   768
# 37  1080
# 38   768
# 39  1080
# 40  1080
# 41  1080
# 42   768
# 43  1080
# 44  1080
# 45  1600
# 46   768
# 47  1080
# 48  1080
# 49   768

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Ips               1303 non-null   int64
#  12  X_res             1303 non-null   int32
#  13  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(1), object(7)
# memory usage: 122.3+ KB

# %%
df.corr()['Price']
# Out:
# Inches    0.068197
# Ram       0.743007
# Weight    0.210370
# Price     1.000000
# Ips       0.252208
# X_res     0.556529
# Y_res     0.552809
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches    0.068197
# Ram       0.743007
# Weight    0.210370
# Price     1.000000
# Ips       0.252208
# X_res     0.556529
# Y_res     0.552809
# ppi       0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7464\23648450.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\hp\AppData\Local\Temp\ipykernel_7464\23648450.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7464\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data Splitting and ML Algorithm model training, Others

# %%
objList = df.select_dtypes(include = "object").columns
print (objList)

#Label Encoding for object to numeric conversion
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for feat in objList:
    df[feat] = le.fit_transform(df[feat].astype(str))

print (df.info())
# Out:
# Index(['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Company    1302 non-null   int32
#  1   TypeName   1302 non-null   int32
#  2   Ram        1302 non-null   int32
#  3   Weight     1302 non-null   float32
#  4   Price      1302 non-null   float64
#  5   Ips        1302 non-null   int64
#  6   ppi        1302 non-null   float64
#  7   Cpu brand  1302 non-null   int32
#  8   HDD        1302 non-null   int64
#  9   SSD        1302 non-null   int64
#  10  Gpu brand  1302 non-null   int32
#  11  os         1302 non-null   int32
# dtypes: float32(1), float64(2), int32(6), int64(3)
# memory usage: 96.6 KB
# None

# %%
X = df.drop(columns=['Price'])

y = np.log(df['Price'])

# %%
X
# Out:
#       Company  TypeName  Ram  Weight  Ips         ppi  Cpu brand   HDD  SSD  \
# 0           1         4    8    1.37    1  226.983005          2     0  128
# 1           1         4    8    1.34    0  127.677940          2     0    0
# 2           7         3    8    1.86    0  141.211998          2     0  256
# 3           1         4   16    1.83    1  220.534624          3     0  512
# 4           1         4    8    1.37    1  226.983005          2     0  256
# ...       ...       ...  ...     ...  ...         ...        ...   ...  ...
# 1298       10         0    4    1.80    1  157.350512          3     0  128
# 1299       10         0   16    1.30    1  276.053530          3     0  512
# 1300       10         3    2    1.50    0  111.935204          4     0    0
# 1301        7         3    6    2.19    0  100.454670          3  1000    0
# 1302        2         3    4    2.20    0  100.454670          4   500    0
#
#       Gpu brand  os
# 0             1   0
# 1             1   0
# 2             1   1
# 3             0   0
# 4             1   0
# ...         ...  ..
# 1298          1   2
# 1299          1   2
# 1300          1   2
# 1301          0   2
# 1302          1   2
#
# [1302 rows x 11 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=0)

# %%
X_train
# Out:
#       Company  TypeName  Ram  Weight  Ips         ppi  Cpu brand   HDD  SSD  \
# 1289        2         4    8    1.20    1  165.632118          4     0  512
# 384         2         4   16    1.10    0  165.632118          3     0  512
# 200         4         1   16    2.65    1  282.423996          3  1000  512
# 279        10         3    8    2.80    0  127.335675          3  2000    0
# 65          2         4   16    1.80    0  141.211998          3     0  512
# ...       ...       ...  ...     ...  ...         ...        ...   ...  ...
# 763         2         4    8    1.20    1  276.053530          2     0  256
# 835         4         1   16    3.21    0  141.211998          3  1000  256
# 1217       10         3    8    2.80    0  106.113062          2  1000    0
# 559         4         3    4    2.18    0  100.454670          1  1000    0
# 684        10         0    8    1.19    1  165.632118          3     0  512
#
#       Gpu brand  os
# 1289          1   2
# 384           1   2
# 200           2   2
# 279           2   1
# 65            2   2
# ...         ...  ..
# 763           1   2
# 835           2   2
# 1217          1   1
# 559           0   2
# 684           1   2
#
# [872 rows x 11 columns]

# %%
y_train
# Out:
# 1289    10.567235
# 384     11.442303
# 200     11.495796
# 279     10.719620
# 65      11.567927
#           ...
# 763     11.004649
# 835     11.903834
# 1217    10.265277
# 559     10.401888
# 684     11.288115
# Name: Price, Length: 872, dtype: float64

# %% [markdown]
# Import ML Librrires for Regression type

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor

# %% [markdown]
# Using LinearRegression ML Algorithm/model

# %%
lr = LinearRegression().fit(X_train,y_train)

y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

print(lr.score(X_test,y_test))
# Out:
# 0.6312392962437152

# %%
x_train= X_train

# %%
x_test= X_test

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
forest = RandomForestRegressor(n_estimators = 1000,
                              criterion = 'mse',
                              random_state = 1,
                              n_jobs = -1)
forest.fit(x_train,y_train)
forest_train_pred = forest.predict(x_train)
forest_test_pred = forest.predict(x_test)

print('MSE train data: %.3f, MSE test data: %.3f' % (
mean_squared_error(y_train,forest_train_pred),
mean_squared_error(y_test,forest_test_pred)))
print('R2 train data: %.3f, R2 test data: %.3f' % (
r2_score(y_train,forest_train_pred),
r2_score(y_test,forest_test_pred)))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# MSE train data: 0.007, MSE test data: 0.050
# R2 train data: 0.982, R2 test data: 0.861

# %% [markdown]
# Other Parts; Either Paper Writing or Deployments(demo in Local Surver,For  Production(app) in Cloud services)
#
# ![image v2.png](attachment:1c95132c-d049-4a4b-a8f0-d9997f49ba58.png)
